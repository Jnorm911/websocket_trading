# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\jnorm\\Projects\\websocket_trading\\evaluation_results.csv")

sorted_df = df.sort_values(by='F1-score', axis=0, ascending=False)
sorted_df
# Out:
#     Candle  Accuracy  F1-score
# 0        1  0.625372      0.65
# 1        2  0.635665      0.65
# 2        3  0.634177      0.64
# 3       53  0.634573      0.64
# 4        4  0.629134      0.63
# 5       51  0.618947      0.63
# 9       60  0.650990      0.62
# 11       6  0.631200      0.62
# 10       5  0.632569      0.62
# 8       42  0.611111      0.62
# 7       49  0.631579      0.62
# 6       50  0.603306      0.62
# 18      57  0.604706      0.61
# 22      59  0.634146      0.61
# 21      15  0.654061      0.61
# 20      16  0.634921      0.61
# 19      58  0.635492      0.61
# 17      23  0.641635      0.61
# 16      33  0.641201      0.61
# 15       7  0.628183      0.61
# 14      25  0.642562      0.61
# 13      26  0.642320      0.61
# 12      34  0.634831      0.61
# 23      19  0.621664      0.60
# 24      13  0.636754      0.60
# 25       8  0.618386      0.60
# 26      48  0.619048      0.60
# 27      29  0.633533      0.60
# 28      44  0.654545      0.60
# ...
