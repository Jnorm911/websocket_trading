# %%
import pandas as pd

# Increase the max_colwidth display option
pd.set_option('display.max_colwidth', None)

df = pd.read_csv("C:\\Users\\jnorm\\Projects\\websocket_trading\\accuracy.csv")

# Filter rows with an accuracy greater than 0.72
filtered_df = df[df['Accuracy'] > 0.72]

# Sort the filtered DataFrame by 'Indicator_Names'
sorted_df = filtered_df.sort_values(by='Indicator_Names', axis=0, ascending=True)

# Display the resulting DataFrame
sorted_df
# Out:
#                                                                                                                Combination  \
# 102831  ('MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9', 'S1', 'S2', 'R3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# 104715             ('MACD_12_26_9', 'MACDs_12_26_9', 'PP', 'R1', 'S2', 'S3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# 57824                                     ('MACD_12_26_9', 'PP', 'R1', 'R3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# 105883                        ('MACD_12_26_9', 'PP', 'R1', 'S2', 'R3', 'S3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# 58202                                     ('MACD_12_26_9', 'PP', 'R2', 'R3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# 58273                                     ('MACD_12_26_9', 'PP', 'S2', 'S3', 'BBU_5_2.0', 'BBB_5_2.0', 'BBP_5_2.0', 'RSI')
# ...
